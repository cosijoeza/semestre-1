# %% [markdown]
# # Funciones de Agregación

# %% [markdown]
# La agregación de datos implica combinar varias filas de una tabla y resumirlas en una
# sola fila, proporcionando información resumida sobre los datos. Esto es especialmente
# útil cuando se trabaja con grandes conjuntos de datos y se requiere obtener
# información precisa.

# %% [markdown]
# El siguiente ejemplo es una base de datos de ventas que tiene las siguientes tablas
#
# `Productos:` Tabla que almacena información de los productos que pueden ser vendidos.
#
# `Clientes:` Tabla que almacena datos de los clientes.
#
# `Pedidos:` Tabla principal que registra cada pedido, asociándolo a un cliente.
#
# `Detalle de pedidos:` Tabla que relaciona los productos con los pedidos, incluyendo la cantidad
# comprada y el precio

# %% [markdown]
# ## Funciones de agregación en SQL

# %% [markdown]
# - `Sum:` calcula la suma de los valores de una columna numérica en una tabla.
#
# - `Count:` cuenta el número de filas en una tabla.
#
# - `Avg:` calcula el promedio de los valores en una columna numérica
#
# - `Max:` obtiene el valor máximo de una columna
#
# - `Min:` obtiene el valor mínimo de una columna
#
# - `Stddev:` Devuelve la desviación del estándar para un conjunto de números.
#
# - `Variance:` Devuelve la variación para un conjunto de números.
#
# - `Mid:` Retorna un número determinado de caracteres que comienza en el caracter
# indicado
#
# - `Length:` Retorna la longitud de la cadena
#
# - `Ucase:` Retorna la cadena en mayúsculas
#
# - `Lcase:` Retorna la cadena en minúsculas
#
# - `Concat(cadena1,cadena2):` Une cadenas.
#
# - `Concat_ws(separador,cadena):` Une cadenas incluyendo un separador

# %%
import mysql.connector
import pandas as pd

# %%
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="x",
    database="ciencia_de_datos"
)
print(mydb)
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x7f3c10315d30>

# %% [markdown]
# ## Ejemplos

# %% [markdown]
# ### Obtener todos los productos y su stock

# %%
sql = "SELECT * FROM productos"
datos = pd.read_sql(sql,mydb)
datos
# Out:
# /tmp/ipykernel_384832/1814603196.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   datos = pd.read_sql(sql,mydb)
#     id_producto      nombre                 descripcion  precio  stock  \
# 0             1  Producto A  Descripción del Producto A   10.00    100
# 1             2  Producto B  Descripción del Producto B   15.50     50
# 2             3  Producto C  Descripción del Producto C   20.75    150
# 3             4  Producto D  Descripción del Producto D    5.00    200
# 4             5  Producto E  Descripción del Producto E   12.99     80
# 5             6  Producto F  Descripción del Producto F    7.50    300
# 6             7  Producto G  Descripción del Producto G   25.00    120
# 7             8  Producto H  Descripción del Producto H   30.00     50
# 8             9  Producto I  Descripción del Producto I   18.50     60
# 9            10  Producto J  Descripción del Producto J   40.00     90
# 10           11  Producto K  Descripción del Producto K    9.99     10
# 11           12  Producto L  Descripción del Producto L    8.75    300
# 12           13  Producto M  Descripción del Producto M   50.00     45
# 13           14  Producto N  Descripción del Producto N    6.50    400
# 14           15  Producto O  Descripción del Producto O   15.00    500
# 15           16  Producto P  Descripción del Producto P   22.00    250
#
#         fecha_creacion
# 0  2024-12-05 19:30:07
# 1  2024-12-05 19:30:07
# 2  2024-12-05 19:32:55
# 3  2024-12-05 19:32:55
# 4  2024-12-05 19:32:55
# 5  2024-12-05 19:32:55
# 6  2024-12-05 19:35:22
# 7  2024-12-05 19:35:22
# 8  2024-12-05 19:35:22
# 9  2024-12-05 19:35:22
# 10 2024-12-05 19:35:22
# 11 2024-12-05 19:35:22
# 12 2024-12-05 19:35:22
# 13 2024-12-05 19:35:22
# 14 2024-12-05 19:35:22
# 15 2024-12-05 19:35:22

# %% [markdown]
# ### Ver productos con bajo stock (menos de 50 unidades)

# %%
sql = "SELECT * FROM productos WHERE stock < 50"
datos = pd.read_sql(sql,mydb)
datos
# Out:
# /tmp/ipykernel_384832/3258124218.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   datos = pd.read_sql(sql,mydb)
#    id_producto      nombre                 descripcion  precio  stock  \
# 0           11  Producto K  Descripción del Producto K    9.99     10
# 1           13  Producto M  Descripción del Producto M   50.00     45
#
#        fecha_creacion
# 0 2024-12-05 19:35:22
# 1 2024-12-05 19:35:22

# %% [markdown]
# ### Ver la cantidad de pedidos de un determinado cliente

# %%
sql = "SELECT c.id_cliente,c.nombre,p.id_pedido FROM clientes c INNER JOIN pedidos p ON c.id_cliente = p.id_cliente WHERE c.id_cliente=1"
datos = pd.read_sql(sql,mydb)
datos
# Out:
# /tmp/ipykernel_384832/1041332067.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   datos = pd.read_sql(sql,mydb)
#    id_cliente      nombre  id_pedido
# 0           1  Juan Pérez          1
# 1           1  Juan Pérez          5
# 2           1  Juan Pérez         12

# %% [markdown]
# Agregamos la función `COUNT` para contar las veces que aparece `id_pedido`

# %%
sql = "SELECT c.id_cliente,c.nombre,COUNT(p.id_pedido) as cantidadPedidos FROM clientes c INNER JOIN pedidos p ON c.id_cliente = p.id_cliente WHERE c.id_cliente=1"
datos = pd.read_sql(sql,mydb)
datos
# Out:
# /tmp/ipykernel_384832/3788641870.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   datos = pd.read_sql(sql,mydb)
#    id_cliente      nombre  cantidadPedidos
# 0           1  Juan Pérez                3

# %%
sql = "SELECT c.id_cliente,c.nombre,p.total as pedidos FROM clientes c INNER JOIN pedidos p ON c.id_cliente = p.id_cliente WHERE c.id_cliente=1"
datos = pd.read_sql(sql,mydb)
datos
# Out:
# /tmp/ipykernel_384832/161516200.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   datos = pd.read_sql(sql,mydb)
#    id_cliente      nombre  pedidos
# 0           1  Juan Pérez     30.0
# 1           1  Juan Pérez     30.0
# 2           1  Juan Pérez    150.0

# %% [markdown]
# Agregamos la función `SUM` para sumar `pedidos`

# %%
sql = "SELECT c.id_cliente, c.nombre,SUM(p.total) as totalPedidos FROM clientes c INNER JOIN pedidos p ON c.id_cliente = p.id_cliente WHERE c.id_cliente=1"
datos = pd.read_sql(sql,mydb)
datos
# Out:
# /tmp/ipykernel_384832/1731426497.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   datos = pd.read_sql(sql,mydb)
#    id_cliente      nombre  totalPedidos
# 0           1  Juan Pérez         210.0

# %% [markdown]
# ### Ver la cantidad de pedidos de los clientes

# %%
sql = "SELECT c.nombre, p.id_pedido AS id_pedido FROM clientes c INNER JOIN pedidos p ON c.id_cliente = p.id_cliente"
datos = pd.read_sql(sql,mydb)
datos
# Out:
# /tmp/ipykernel_384832/1466534515.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   datos = pd.read_sql(sql,mydb)
#             nombre  id_pedido
# 0       Juan Pérez          1
# 1       Juan Pérez          5
# 2       Juan Pérez         12
# 3      María López          2
# 4      María López         13
# 5    Carlos García          3
# 6    Carlos García         14
# 7       Ana Torres          4
# 8       Ana Torres         15
# 9   Luis Fernández          6
# 10  Paula Martínez          7
# 11    Ricardo Díaz          8
# 12     Sofía Reyes          9
# 13  Fernando Ortiz         10
# 14  Gabriela Silva         11

# %% [markdown]
# Para que solo tengamos un solo nombre, agrupamos con `GROUP BY` por el `id_cliente`

# %%
sql = "SELECT c.nombre, p.id_pedido AS total_pedidos FROM clientes c INNER JOIN pedidos p ON c.id_cliente = p.id_cliente GROUP BY c.id_cliente"
datos = pd.read_sql(sql,mydb)
datos
# Out:
# /tmp/ipykernel_384832/469980676.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   datos = pd.read_sql(sql,mydb)
#            nombre  total_pedidos
# 0      Juan Pérez              1
# 1     María López              2
# 2   Carlos García              3
# 3      Ana Torres              4
# 4  Luis Fernández              6
# 5  Paula Martínez              7
# 6    Ricardo Díaz              8
# 7     Sofía Reyes              9
# 8  Fernando Ortiz             10
# 9  Gabriela Silva             11

# %%
sql = "SELECT c.nombre, COUNT(p.id_pedido) AS total_pedidos FROM clientes c INNER JOIN pedidos p ON c.id_cliente = p.id_cliente GROUP BY c.id_cliente"
datos = pd.read_sql(sql,mydb)
datos
# Out:
# /tmp/ipykernel_384832/2761252866.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   datos = pd.read_sql(sql,mydb)
#            nombre  total_pedidos
# 0      Juan Pérez              3
# 1     María López              2
# 2   Carlos García              2
# 3      Ana Torres              2
# 4  Luis Fernández              1
# 5  Paula Martínez              1
# 6    Ricardo Díaz              1
# 7     Sofía Reyes              1
# 8  Fernando Ortiz              1
# 9  Gabriela Silva              1

# %% [markdown]
# ### Ver clientes con más de un pedido

# %% [markdown]
# Agregamos un condicional `HAVING` para filtrar que el numero de `id_pedido` sea mayor que 1

# %%
sql = "SELECT c.nombre, COUNT(p.id_pedido) AS total_pedidos FROM clientes c JOIN pedidos p ON c.id_cliente = p.id_cliente GROUP BY c.id_cliente HAVING COUNT(p.id_pedido) > 1"
datos = pd.read_sql(sql,mydb)
datos
# Out:
# /tmp/ipykernel_384832/598723545.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   datos = pd.read_sql(sql,mydb)
#           nombre  total_pedidos
# 0     Juan Pérez              3
# 1    María López              2
# 2  Carlos García              2
# 3     Ana Torres              2

# %% [markdown]
# ### Cantidad total de productos vendidos

# %%
sql = "SELECT id_pedido,cantidad AS total_productos_vendidos FROM detalle_pedidos"
datos = pd.read_sql(sql,mydb)
datos
# Out:
# /tmp/ipykernel_384832/3421500036.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   datos = pd.read_sql(sql,mydb)
#     id_pedido  total_productos_vendidos
# 0           1                         2
# 1           2                         2
# 2           2                         1
# 3           3                        10
# 4           3                         2
# 5           4                        20
# 6           4                         3
# 7           5                         2
# 8           5                        10
# 9           6                        20
# 10          6                         5
# 11          7                         3
# 12          7                         6
# 13          8                        24
# 14          8                         2
# 15          9                        30
# 16          9                        12
# 17         10                         4
# 18         10                         5

# %% [markdown]
# Con la función

# %%
sql = "SELECT SUM(cantidad) AS total_productos_vendidos FROM detalle_pedidos"
datos = pd.read_sql(sql,mydb)
datos
# Out:
# /tmp/ipykernel_384832/2123857227.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   datos = pd.read_sql(sql,mydb)
#    total_productos_vendidos
# 0                     163.0

# %% [markdown]
# ### Obtener los productos más vendidos

# %%
sql = "SELECT *, cantidad as totalCantidad FROM `detalle_pedidos`"
datos = pd.read_sql(sql,mydb)
datos
# Out:
# /tmp/ipykernel_384832/581924115.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   datos = pd.read_sql(sql,mydb)
#     id_detalle  id_pedido  id_producto  cantidad  precio_unitario  subtotal  \
# 0            1          1            1         2            10.00     20.00
# 1            2          2            3         2            20.75     41.50
# 2            3          2            1         1            10.00     10.00
# 3            4          3            4        10             5.00     50.00
# 4            5          3            5         2            12.99     25.98
# 5            6          4            6        20             7.50    150.00
# 6            7          4            2         3            15.50     46.50
# 7            8          5            7         2            50.00    100.00
# 8            9          5            8        10             6.50     65.00
# 9           10          6            9        20            15.00    300.00
# 10          11          6           10         5            22.00    110.00
# 11          12          7            4         3            40.00    120.00
# 12          13          7            5         6            12.99     77.94
# 13          14          8            6        24             7.50    180.00
# 14          15          8            2         2            15.50     31.00
# 15          16          9            1        30            10.00    300.00
# 16          17          9            3        12            20.75    249.00
# 17          18         10           11         4            30.00    120.00
# 18          19         10           12         5            18.50     92.50
#
#     totalCantidad
# 0               2
# 1               2
# 2               1
# 3              10
# 4               2
# 5              20
# 6               3
# 7               2
# 8              10
# 9              20
# 10              5
# 11              3
# 12              6
# 13             24
# 14              2
# 15             30
# 16             12
# 17              4
# 18              5

# %%
sql = "SELECT *, cantidad as totalCantidad FROM `detalle_pedidos` ORDER BY id_producto"
datos = pd.read_sql(sql,mydb)
datos
# Out:
# /tmp/ipykernel_384832/4291464219.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   datos = pd.read_sql(sql,mydb)
#     id_detalle  id_pedido  id_producto  cantidad  precio_unitario  subtotal  \
# 0            1          1            1         2            10.00     20.00
# 1           16          9            1        30            10.00    300.00
# 2            3          2            1         1            10.00     10.00
# 3           15          8            2         2            15.50     31.00
# 4            7          4            2         3            15.50     46.50
# 5            2          2            3         2            20.75     41.50
# 6           17          9            3        12            20.75    249.00
# 7            4          3            4        10             5.00     50.00
# 8           12          7            4         3            40.00    120.00
# 9            5          3            5         2            12.99     25.98
# 10          13          7            5         6            12.99     77.94
# 11          14          8            6        24             7.50    180.00
# 12           6          4            6        20             7.50    150.00
# 13           8          5            7         2            50.00    100.00
# 14           9          5            8        10             6.50     65.00
# 15          10          6            9        20            15.00    300.00
# 16          11          6           10         5            22.00    110.00
# 17          18         10           11         4            30.00    120.00
# 18          19         10           12         5            18.50     92.50
#
#     totalCantidad
# 0               2
# 1              30
# 2               1
# 3               2
# 4               3
# 5               2
# 6              12
# 7              10
# 8               3
# 9               2
# 10              6
# 11             24
# 12             20
# 13              2
# 14             10
# 15             20
# 16              5
# 17              4
# 18              5

# %%
sql = "SELECT P.nombre, SUM(cantidad) as totalCantidad FROM detalle_pedidos DP INNER JOIN productos P ON DP.id_producto=P.id_producto GROUP BY(DP.id_producto)"
datos = pd.read_sql(sql,mydb)
datos
# Out:
# /tmp/ipykernel_384832/3930219743.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   datos = pd.read_sql(sql,mydb)
#         nombre  totalCantidad
# 0   Producto A           33.0
# 1   Producto B            5.0
# 2   Producto C           14.0
# 3   Producto D           13.0
# 4   Producto E            8.0
# 5   Producto F           44.0
# 6   Producto G            2.0
# 7   Producto H           10.0
# 8   Producto I           20.0
# 9   Producto J            5.0
# 10  Producto K            4.0
# 11  Producto L            5.0
