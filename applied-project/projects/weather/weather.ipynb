# %% [markdown]
# # 2.1 Obtención de datos mediante APIs

# %%
import requests
import time
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.by import By
from unidecode import unidecode

# %%
# Set up the WebDriver
driver = webdriver.Chrome()

# Open the Python website
driver.get(
    "https://cuentame.inegi.org.mx/monografias/informacion/oax/territorio/div_municipal.aspx?tema=me&e=20"
)

# Wait to url is ready
time.sleep(5)

# Read and save information
oax_municipalities = []
for i in range(1, 571):
    state = driver.find_element(
        By.XPATH, "//*[@id='keywords2']/tbody/tr[" + str(i) + "]/td[2]"
    )
    # Save and clean string
    oax_municipalities.append(unidecode(state.text))

# Close the browser
driver.quit()

# %%
municipalities = oax_municipalities[151:161]
municipalities
# Out:
# ['San Francisco Tlapancingo',
#  'San Gabriel Mixtepec',
#  'San Ildefonso Amatlan',
#  'San Ildefonso Sola',
#  'San Ildefonso Villa Alta',
#  'San Jacinto Amilpas',
#  'San Jacinto Tlacotepec',
#  'San Jeronimo Coatlan',
#  'San Jeronimo Silacayoapilla',
#  'San Jeronimo Sosola']

# %% [markdown]
# Lista de estados de donde quiero obtener la información.

# %%
locations = [
    "Aguascalientes",
    "Baja California",
    "Baja California Sur",
    "Campeche",
    "Chiapas",
    "Chihuahua",
    "Ciudad de México",
    "Coahuila",
    "Colima",
    "Durango",
    "Estado de México",
    "Guanajuato",
    "Guerrero",
    "Hidalgo",
    "Jalisco",
    "Michoacán",
    "Morelos",
    "Nayarit",
    "Nuevo León",
    "Oaxaca",
    "Puebla",
    "Querétaro",
    "Quintana Roo",
    "San Luis Potosí",
    "Sinaloa",
    "Sonora",
    "Tabasco",
    "Tamaulipas",
    "Tlaxcala",
    "Veracruz",
    "Yucatán",
    "Zacatecas",
]

# %%
len(municipalities)
# Out:
# 10

# %% [markdown]
# ## Envío de solicitudes a la API

# %%
def getApiData(endpoint, payload, locations, getFirst):
    data_collected = []
    for location in locations:
        payload["q"] = location
        try:
            time.sleep(5)
            r = requests.get(url=endpoint, params=payload)
            if r.status_code == 200:
                json = r.json()
                if getFirst:
                    data_collected.append(json[0])
                else:
                    data_collected.append(json)
        except:
            continue
    return data_collected

# %%
def getApiDataOax(endpoint, payload, municipalities, getFirst):
    data_collected = []
    for municipality in municipalities:
        print(municipality)
        payload["q"] = "'name':'" + municipality + "','region':'oaxaca'"
        try:
            time.sleep(5)
            r = requests.get(url=endpoint, params=payload)
            if r.status_code == 200:
                json = r.json()
                if getFirst:
                    data_collected.append(json[0])
                else:
                    data_collected.append(json)
        except:
            continue
    return data_collected

# %%
# =============CODE FOR DEBUG==============
"""
municipalities = oax_states[80:84]
data_collected_0 = []
data_collected = []
for municipality in municipalities:
    payload["q"] = "'name':'" + municipality + "','region':'oaxaca'"
    r = requests.get(url=endpoint + search, params=payload)
    if r.status_code == 200:
        json = r.json()
        data_collected_0.append(json[0])
        data_collected.append(json)
"""

# %%
endpoint = "http://api.weatherapi.com/v1/"
payload = {"key": "cf111e82db2c47119ea162327242212"}

# %%
search = "/search.json"

# %%
data_search_oax = getApiDataOax(
    endpoint=endpoint + search,
    payload=payload,
    municipalities=oax_states[80:84],
    getFirst=True,
)
# Out:
# San Agustin Atenango
# San Agustin Chayuco
# San Agustin de las Juntas
# San Agustin Etla

# %%
data_search = getApiData(
    endpoint=endpoint + search, payload=payload, locations=locations, getFirst=True
)
# Out:
# ['San Agustin Atenango',
#  'San Agustin Chayuco',
#  'San Agustin de las Juntas',
#  'San Agustin Etla']

# %%
current = "/current.json"

# %%
data_current = getApiData(
    endpoint=endpoint + current, payload=payload, locations=locations, getFirst=False
)

# %%
astronomy = "/astronomy.json"

# %%
data_astronomy = getApiData(
    endpoint=endpoint + astronomy, payload=payload, locations=locations, getFirst=False
)

# %%
normalized_data_search_oax = pd.json_normalize(data_collected_0)
df_search = pd.DataFrame.from_dict(normalized_data_search_oax)
df_search.head()
# Out:
#         id                       name  region country    lat    lon  \
# 0  3209970       San Agustin Atenango  Oaxaca  Mexico  17.61 -98.01
# 1  3208245        San Agustin Chayuco  Oaxaca  Mexico  17.25 -98.02
# 2  3217385  San Agustin De Las Juntas  Oaxaca  Mexico  17.00 -96.71
# 3  3208244           San Agustin Etla  Oaxaca  Mexico  17.19 -96.77
#
#                                        url
# 0       san-agustin-atenango-oaxaca-mexico
# 1        san-agustin-chayuco-oaxaca-mexico
# 2  san-agustin-de-las-juntas-oaxaca-mexico
# 3           san-agustin-etla-oaxaca-mexico

# %%
data_search_oax = getApiData(
    endpoint=endpoint + search, payload=payload, locations=oax_states, getFirst=True
)

# %%
normalized_data_search = pd.json_normalize(data_search)
df_search_temp = pd.DataFrame.from_dict(normalized_data_search).add_prefix("location.")
df_search = df_search_temp.drop(["location.lat", "location.lon"], axis=1)
df_search
# Out:
#     location.id                  location.name      location.region  \
# 0       3296893                 Aguascalientes       Aguascalientes
# 1       3242121                Baja California              Chiapas
# 2       3274846    Agrodelicias De La Baja Sur  Baja California Sur
# 3       3220121                       Campeche             Campeche
# 4       3241759                  Chiapas Nuevo              Chiapas
# 5       3295284                      Chihuahua            Chihuahua
# 6       3198637                  Ciudad Jardin               México
# 7       3182624                       Coahuila     San Luis PotosÃ­
# 8       3325202                         Colima               Colima
# 9        707103                        Durango           Pais Vasco
# 10      3242870               Estado De Mexico              Tabasco
# 11      3265153                     Guanajuato           Guanajuato
# 12      3195691                       Guerrero              Hidalgo
# 13      3295282             Hidalgo Del Parral            Chihuahua
# 14      3255072  Jalisco Del Refugio (Jalisco)              Jalisco
# 15      3241750                      Michoacán              Chiapas
# 16      3311285                        Morelos           MichoacÃ¡n
# 17      3220022              Nayarit Castellot             Campeche
# 18      4060860                          Nuevo           California
# 19      3217453                         Oaxaca               Oaxaca
# 20      3225853                         Puebla               Puebla
# 21      3191137                  Tequisquiapan            Querétaro
# 22      3233139                   Quintana Roo              Chiapas
# 23       111135                       San Luis             San Luis
# 24      3303246               Sinaloa De Leyva              Sinaloa
# 25      3165536                         Sonora       Veracruz-Llave
# 26      3279652                        Tabasco            Zacatecas
# 27      3234571                     Tamaulipas              Chiapas
# 28      3226948       Tlaxcala De Xicohtencatl             Tlaxcala
# 29      3165851                       Veracruz       Veracruz-Llave
# 30      3143977                        Yucatán             Coahuila
# 31      3279671                      Zacatecas            Zacatecas
#
#                 location.country  \
# 0                         Mexico
# 1                         Mexico
# 2                         Mexico
# 3                         Mexico
# 4                         Mexico
# 5                         Mexico
# 6                         Mexico
# 7                         Mexico
# 8                         Mexico
# 9                          Spain
# 10                        Mexico
# 11                        Mexico
# 12                        Mexico
# 13                        Mexico
# 14                        Mexico
# 15                        Méjico
# 16                        Mexico
# 17                        Mexico
# 18  USA United States of America
# 19                        Mexico
# 20                        Mexico
# 21                        Mexico
# 22                        Mexico
# 23                     Argentina
# 24                        Mexico
# 25                        Mexico
# 26                        Mexico
# 27                        Mexico
# 28                        Mexico
# 29                        Mexico
# 30                        Méjico
# 31                        Mexico
#
#                                          location.url
# 0                aguascalientes-aguascalientes-mexico
# 1                      baja-california-chiapas-mexico
# 2   agrodelicias-de-la-baja-sur-baja-california-su...
# 3                            campeche-campeche-mexico
# 4                        chiapas-nuevo-chiapas-mexico
# 5                          chihuahua-chihuahua-mexico
# 6                          ciudad-jardin-mxico-mexico
# 7                      coahuila-san-luis-potos-mexico
# 8                                colima-colima-mexico
# 9                            durango-pais-vasco-spain
# 10                    estado-de-mexico-tabasco-mexico
# 11                       guanajuato-guanajuato-mexico
# 12                            guerrero-hidalgo-mexico
# 13                hidalgo-del-parral-chihuahua-mexico
# 14         jalisco-del-refugio-jalisco-jalisco-mexico
# 15                             michoacn-chiapas-mjico
# 16                            morelos-michoacn-mexico
# 17                  nayarit-castellot-campeche-mexico
# 18      nuevo-california-usa-united-states-of-america
# 19                               oaxaca-oaxaca-mexico
# 20                               puebla-puebla-mexico
# 21                      tequisquiapan-quertaro-mexico
# 22                        quintana-roo-chiapas-mexico
# 23                        san-luis-san-luis-argentina
# 24                    sinaloa-de-leyva-sinaloa-mexico
# 25                       sonora-veracruz-llave-mexico
# 26                           tabasco-zacatecas-mexico
# 27                          tamaulipas-chiapas-mexico
# 28           tlaxcala-de-xicohtencatl-tlaxcala-mexico
# 29                     veracruz-veracruz-llave-mexico
# 30                              yucatn-coahuila-mjico
# 31                         zacatecas-zacatecas-mexico

# %%
normalized_data_current = pd.json_normalize(data_current)
df_current = pd.DataFrame.from_dict(normalized_data_current)
df_current.head()
# Out:
#                  location.name      location.region location.country  \
# 0               Aguascalientes       Aguascalientes           Mexico
# 1              Baja California              Chiapas           Mexico
# 2  Agrodelicias De La Baja Sur  Baja California Sur           Mexico
# 3                     Campeche             Campeche           Mexico
# 4                Chiapas Nuevo              Chiapas           Mexico
#
#    location.lat  location.lon       location.tz_id  location.localtime_epoch  \
# 0       21.8823     -102.2826  America/Mexico_City                1735588899
# 1       16.4333      -93.7953  America/Mexico_City                1735588964
# 2       23.7750     -110.2737     America/Mazatlan                1735588911
# 3       19.8380      -90.5277       America/Merida                1735588916
# 4       16.4553      -93.8272  America/Mexico_City                1735588922
#
#   location.localtime  current.last_updated_epoch current.last_updated  ...  \
# 0   2024-12-30 14:01                  1735588800     2024-12-30 14:00  ...
# 1   2024-12-30 14:02                  1735588800     2024-12-30 14:00  ...
# 2   2024-12-30 13:01                  1735588800     2024-12-30 13:00  ...
# 3   2024-12-30 14:01                  1735588800     2024-12-30 14:00  ...
# 4   2024-12-30 14:02                  1735588800     2024-12-30 14:00  ...
#
#    current.windchill_f  current.heatindex_c  current.heatindex_f  \
# 0                 76.3                 23.4                 74.1
# 1                 80.7                 28.0                 82.3
# 2                 76.4                 25.5                 77.9
# 3                 82.0                 31.8                 89.3
# 4                 80.7                 28.0                 82.3
#
#   current.dewpoint_c current.dewpoint_f  current.vis_km  current.vis_miles  \
# 0               -2.7               27.1            10.0                6.0
# 1               16.8               62.3            10.0                6.0
# 2               13.6               56.6            10.0                6.0
# 3               24.0               75.2            11.0                6.0
# 4               16.8               62.3            10.0                6.0
#
#    current.uv  current.gust_mph current.gust_kph
# 0         6.0               6.7             10.8
# 1         5.3               5.4              8.7
# 2         5.9              10.8             17.3
# 3         4.5               9.3             15.0
# 4         5.3               5.4              8.7
#
# [5 rows x 39 columns]

# %%
normalized_data_astronomy = pd.json_normalize(data_astronomy)
df_astronomy = pd.DataFrame.from_dict(normalized_data_astronomy)
df_astronomy.head()
# Out:
#                  location.name      location.region location.country  \
# 0               Aguascalientes       Aguascalientes           Mexico
# 1              Baja California              Chiapas           Mexico
# 2  Agrodelicias De La Baja Sur  Baja California Sur           Mexico
# 3                     Campeche             Campeche           Mexico
# 4                Chiapas Nuevo              Chiapas           Mexico
#
#    location.lat  location.lon       location.tz_id  location.localtime_epoch  \
# 0       21.8823     -102.2826  America/Mexico_City                1735586980
# 1       16.4333      -93.7953  America/Mexico_City                1735589080
# 2       23.7750     -110.2737     America/Mazatlan                1735589086
# 3       19.8380      -90.5277       America/Merida                1735588370
# 4       16.4553      -93.8272  America/Mexico_City                1735589160
#
#   location.localtime astronomy.astro.sunrise astronomy.astro.sunset  \
# 0   2024-12-30 13:29                07:28 AM               06:16 PM
# 1   2024-12-30 14:04                06:43 AM               05:53 PM
# 2   2024-12-30 13:04                07:03 AM               05:45 PM
# 3   2024-12-30 13:52                06:36 AM               05:34 PM
# 4   2024-12-30 14:06                06:43 AM               05:53 PM
#
#   astronomy.astro.moonrise astronomy.astro.moonset astronomy.astro.moon_phase  \
# 0                 07:24 AM                06:08 PM                   New Moon
# 1                 06:34 AM                05:46 PM                   New Moon
# 2                 07:02 AM                05:36 PM                   New Moon
# 3                 06:29 AM                05:24 PM                   New Moon
# 4                 06:34 AM                05:46 PM                   New Moon
#
#    astronomy.astro.moon_illumination  astronomy.astro.is_moon_up  \
# 0                                  1                           0
# 1                                  1                           0
# 2                                  1                           0
# 3                                  1                           0
# 4                                  1                           0
#
#    astronomy.astro.is_sun_up
# 0                          1
# 1                          1
# 2                          1
# 3                          1
# 4                          1

# %%
df_astronomy_current = pd.merge(
    df_astronomy,
    df_current,
    on=[
        "location.name",
        "location.region",
        "location.country",
        "location.lat",
        "location.lon",
        "location.tz_id",
    ],
)
df_astronomy_current
# Out:
#                     location.name      location.region  \
# 0                  Aguascalientes       Aguascalientes
# 1                 Baja California              Chiapas
# 2     Agrodelicias De La Baja Sur  Baja California Sur
# 3                        Campeche             Campeche
# 4                   Chiapas Nuevo              Chiapas
# 5                       Chihuahua            Chihuahua
# 6                   Ciudad Jardin               México
# 7                        Coahuila     San Luis PotosÃ­
# 8                          Colima               Colima
# 9                         Durango           Pais Vasco
# 10               Estado De Mexico              Tabasco
# 11                     Guanajuato           Guanajuato
# 12                       Guerrero              Hidalgo
# 13             Hidalgo Del Parral            Chihuahua
# 14  Jalisco Del Refugio (Jalisco)              Jalisco
# 15                      Michoacán              Chiapas
# 16                        Morelos           MichoacÃ¡n
# 17              Nayarit Castellot             Campeche
# 18                          Nuevo           California
# 19                         Oaxaca               Oaxaca
# 20                         Puebla               Puebla
# 21                  Tequisquiapan            Querétaro
# 22                   Quintana Roo              Chiapas
# 23                       San Luis             San Luis
# 24               Sinaloa De Leyva              Sinaloa
# 25                         Sonora       Veracruz-Llave
# 26                        Tabasco            Zacatecas
# 27                     Tamaulipas              Chiapas
# 28       Tlaxcala De Xicohtencatl             Tlaxcala
# 29                       Veracruz       Veracruz-Llave
# 30                        Yucatán             Coahuila
# 31                      Zacatecas            Zacatecas
#
#                 location.country  location.lat  location.lon  \
# 0                         Mexico       21.8823     -102.2826
# 1                         Mexico       16.4333      -93.7953
# 2                         Mexico       23.7750     -110.2737
# 3                         Mexico       19.8380      -90.5277
# 4                         Mexico       16.4553      -93.8272
# 5                         Mexico       28.6353     -106.0889
# 6                         Mexico       19.4222      -99.0167
# 7                         Mexico       21.9313     -100.7511
# 8                         Mexico       19.2434     -103.7277
# 9                          Spain       43.1667       -2.6167
# 10                        Mexico       18.0198      -90.8811
# 11                        Mexico       21.0186     -101.2591
# 12                        Mexico       20.3669      -99.0075
# 13                        Mexico       26.9296     -105.6662
# 14                        Mexico       21.9911     -103.2340
# 15                        Méjico       16.1494      -92.0636
# 16                        Mexico       19.6489     -101.2389
# 17                        Mexico       19.2258      -90.2500
# 18  USA United States of America       33.8171     -117.0960
# 19                        Mexico       17.0711      -96.7191
# 20                        Mexico       19.0433      -98.2019
# 21                        Mexico       20.5225      -99.8917
# 22                        Mexico       16.7656      -91.6575
# 23                     Argentina      -33.3000      -66.3500
# 24                        Mexico       25.8219     -108.2226
# 25                        Mexico       19.1122      -96.6353
# 26                        Mexico       21.8629     -102.9111
# 27                        Mexico       17.4636      -92.3083
# 28                        Mexico       19.3191      -98.1998
# 29                        Mexico       19.1810      -96.1429
# 30                        Méjico       25.8800     -103.3303
# 31                        Mexico       22.7684     -102.5814
#
#                 location.tz_id  location.localtime_epoch_x  \
# 0          America/Mexico_City                  1735586980
# 1          America/Mexico_City                  1735589080
# 2             America/Mazatlan                  1735589086
# 3               America/Merida                  1735588370
# 4          America/Mexico_City                  1735589160
# 5            America/Chihuahua                  1735587008
# 6          America/Mexico_City                  1735589108
# 7          America/Mexico_City                  1735589142
# 8          America/Mexico_City                  1735589176
# 9                Europe/Madrid                  1735589184
# 10              America/Merida                  1735587035
# 11         America/Mexico_City                  1735587040
# 12         America/Mexico_City                  1735589140
# 13           America/Chihuahua                  1735587051
# 14         America/Mexico_City                  1735589160
# 15         America/Mexico_City                  1735589158
# 16         America/Mexico_City                  1735588441
# 17              America/Merida                  1735587073
# 18         America/Los_Angeles                  1735587078
# 19         America/Mexico_City                  1735589179
# 20         America/Mexico_City                  1735589184
# 21         America/Mexico_City                  1735589190
# 22         America/Mexico_City                  1735589195
# 23  America/Argentina/San_Luis                  1735591330
# 24            America/Mazatlan                  1735589244
# 25         America/Mexico_City                  1735589271
# 26         America/Mexico_City                  1735588496
# 27         America/Mexico_City                  1735589251
# 28         America/Mexico_City                  1735587133
# 29         America/Mexico_City                  1735589293
# 30           America/Monterrey                  1735589239
# 31         America/Mexico_City                  1735589273
#
#    location.localtime_x astronomy.astro.sunrise astronomy.astro.sunset  ...  \
# 0      2024-12-30 13:29                07:28 AM               06:16 PM  ...
# 1      2024-12-30 14:04                06:43 AM               05:53 PM  ...
# 2      2024-12-30 13:04                07:03 AM               05:45 PM  ...
# 3      2024-12-30 13:52                06:36 AM               05:34 PM  ...
# 4      2024-12-30 14:06                06:43 AM               05:53 PM  ...
# 5      2024-12-30 13:30                07:57 AM               06:18 PM  ...
# 6      2024-12-30 14:05                07:10 AM               06:08 PM  ...
# 7      2024-12-30 14:05                07:22 AM               06:10 PM  ...
# 8      2024-12-30 14:06                07:28 AM               06:27 PM  ...
# 9      2024-12-30 21:06                08:42 AM               05:45 PM  ...
# 10     2024-12-30 13:30                06:34 AM               05:39 PM  ...
# 11     2024-12-30 13:30                07:22 AM               06:14 PM  ...
# 12     2024-12-30 14:05                07:12 AM               06:06 PM  ...
# 13     2024-12-30 13:30                07:52 AM               06:20 PM  ...
# 14     2024-12-30 14:06                07:32 AM               06:20 PM  ...
# 15     2024-12-30 14:05                06:35 AM               05:47 PM  ...
# 16     2024-12-30 13:54                07:19 AM               06:17 PM  ...
# 17     2024-12-30 13:31                06:34 AM               05:34 PM  ...
# 18     2024-12-30 11:31                06:53 AM               04:50 PM  ...
# 19     2024-12-30 14:06                06:56 AM               06:04 PM  ...
# 20     2024-12-30 14:06                07:06 AM               06:06 PM  ...
# 21     2024-12-30 14:06                07:15 AM               06:10 PM  ...
# 22     2024-12-30 14:06                06:35 AM               05:44 PM  ...
# 23     2024-12-30 17:42                06:18 AM               08:38 PM  ...
# 24     2024-12-30 13:07                06:59 AM               05:33 PM  ...
# 25     2024-12-30 14:07                06:59 AM               05:59 PM  ...
# 26     2024-12-30 13:54                07:30 AM               06:19 PM  ...
# 27     2024-12-30 14:07                06:39 AM               05:45 PM  ...
# 28     2024-12-30 13:32                07:06 AM               06:05 PM  ...
# 29     2024-12-30 14:08                06:58 AM               05:57 PM  ...
# 30     2024-12-30 14:07                07:40 AM               06:13 PM  ...
# 31     2024-12-30 14:07                07:31 AM               06:16 PM  ...
#
#    current.windchill_f current.heatindex_c current.heatindex_f  \
# 0                 76.3                23.4                74.1
# 1                 80.7                28.0                82.3
# 2                 76.4                25.5                77.9
# 3                 82.0                31.8                89.3
# 4                 80.7                28.0                82.3
# 5                 78.7                24.4                76.0
# 6                 72.9                22.2                72.0
# 7                 75.5                23.1                73.6
# 8                 90.8                31.5                88.7
# 9                 44.8                 7.5                45.4
# 10                83.5                33.2                91.7
# 11                72.0                22.3                72.2
# 12                78.2                24.3                75.7
# 13                81.1                25.5                77.9
# 14                77.4                23.8                74.9
# 15                74.8                25.0                77.0
# 16                74.2                22.9                73.2
# 17                86.9                35.1                95.2
# 18                61.0                16.1                61.0
# 19                74.6                23.1                73.6
# 20                73.8                23.5                74.2
# 21                73.2                22.3                72.1
# 22                77.3                26.3                79.4
# 23                92.2                31.5                88.7
# 24                78.9                24.7                76.4
# 25                77.0                26.1                78.9
# 26                72.0                21.6                70.8
# 27                82.3                31.8                89.3
# 28                72.1                22.3                72.1
# 29                76.8                27.1                80.8
# 30                65.0                18.4                65.1
# 31                71.9                21.8                71.2
#
#     current.dewpoint_c  current.dewpoint_f  current.vis_km  current.vis_miles  \
# 0                 -2.7                27.1            10.0                6.0
# 1                 16.8                62.3            10.0                6.0
# 2                 13.6                56.6            10.0                6.0
# 3                 24.0                75.2            11.0                6.0
# 4                 16.8                62.3            10.0                6.0
# 5                -11.0                12.3            16.0                9.0
# 6                 -1.5                29.4            11.0                6.0
# 7                 -1.3                29.7            19.0               11.0
# 8                 10.5                50.9            10.0                6.0
# 9                  2.7                36.8            10.0                6.0
# 10                23.9                75.1            10.0                6.0
# 11                 2.2                35.9            16.0                9.0
# 12                 0.7                33.3            10.0                6.0
# 13               -14.7                 5.6            10.0                6.0
# 14                -2.3                27.9            10.0                6.0
# 15                14.5                58.1            10.0                6.0
# 16                 2.5                36.6            13.0                8.0
# 17                23.8                74.9            10.0                6.0
# 18                 6.2                43.1            16.0                9.0
# 19                 1.3                34.3            13.0                8.0
# 20                 4.5                40.1            13.0                8.0
# 21                -3.0                26.6            16.0                9.0
# 22                17.7                63.8            10.0                6.0
# 23                 8.0                46.4            10.0                6.0
# 24                 3.3                37.9            10.0                6.0
# 25                16.0                60.8            10.0                6.0
# 26                -1.9                28.5            10.0                6.0
# 27                23.7                74.7            10.0                6.0
# 28                 2.2                35.9            13.0                8.0
# 29                21.9                71.5            10.0                6.0
# 30                -5.8                21.6            10.0                6.0
# 31                -6.9                19.6            13.0                8.0
#
#    current.uv  current.gust_mph current.gust_kph
# 0         6.0               6.7             10.8
# 1         5.3               5.4              8.7
# 2         5.9              10.8             17.3
# 3         4.5               9.3             15.0
# 4         5.3               5.4              8.7
# 5         4.7               2.6              4.1
# 6         6.5               3.6              5.8
# 7         5.9               8.0             12.9
# 8         6.4               5.4              8.7
# 9         0.0               4.8              7.7
# 10        4.1               3.2              5.1
# 11        7.2              10.3             16.6
# 12        6.1               8.9             14.3
# 13        5.3               6.7             10.8
# 14        6.2               8.7             14.1
# 15        6.2               4.1              6.6
# 16        7.8               6.7             10.8
# 17        2.8               6.7             10.8
# 18        2.8               6.7             10.8
# 19        6.7               6.7             10.8
# 20        6.4               6.4             10.4
# 21        6.3               7.2             11.6
# 22        5.6               2.8              4.6
# 23        5.8              15.9             25.7
# 24        5.5               2.9              4.7
# 25        5.8               6.2              9.9
# 26        7.0               4.1              6.6
# 27        3.9               5.4              8.7
# 28        6.4               6.7             10.8
# 29        5.1               9.1             14.6
# 30        5.8               4.1              6.6
# 31        6.1              10.8             17.4
#
# [32 rows x 49 columns]

# %%
df_full = pd.merge(
    df_search,
    df_astronomy_current,
    on=[
        "location.name",
        "location.region",
        "location.country",
    ],
)

# %%
df_full.to_csv("dataset/dataset_raw/weather.csv")
